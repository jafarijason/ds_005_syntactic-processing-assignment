# %% [markdown]
# ## Identifying Entities in Healthcare Data

# %% [markdown]
# 1. Import Necessary Libraries

# %%
import pandas as pd
import spacy
from sklearn_crfsuite import CRF, metrics
from collections import Counter
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 1.3 MB/s eta 0:00:000:00:01m eta 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
model = spacy.load("en_core_web_sm")

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# The dataset provided is in the form of one word per line. Let's understand the format of data below:
#
# - Suppose there are x words in a sentence, then there will be x continuous lines with one word in each line.
# - Further, the two sentences are separated by empty lines. The labels for the data follow the same format.

# %% [markdown]
# ## We need to pre-process the data to recover the complete sentences and their labels.
#
# ### Construct the proper sentences from individual words and print the 5 sentences.

# %%
# Reading the train_sent,test_sent,train_label,test_label
with open('train_sent', 'r') as train_sent_file:
  train_words = train_sent_file.readlines()

with open('train_label', 'r') as train_labels_file:
  train_labels_words = train_labels_file.readlines()

with open('test_sent', 'r') as test_sent_file:
  test_words = test_sent_file.readlines()

with open('test_label', 'r') as test_labels_file:
  test_labels_words = test_labels_file.readlines()

# %%
print("Token count in training set", len(train_words))
print("Token count in training labels", len(train_labels_words))
print("Token count in test set", len(test_words))
print("Token count in test labels", len(test_labels_words))
# Out:
# Token count in training set 48501
# Token count in training labels 48501
# Token count in test set 19674
# Token count in test labels 19674

# %%
def convert_to_sentences(dataset):
    sent_list = []
    sent = ""
    for entity in dataset:
        if entity != '\n':
            sent = sent + entity[:-1] + " "       # Adding word/label to current sentence / sequence of labels 
        else: 
            sent_list.append(sent[:-1])           # Getting rid of the space added after the last entity.
            sent = ""
    return sent_list

# %%
train_sentences = convert_to_sentences(train_words)

# print first 5 train sentences
for sentence in train_sentences[:5]:
    print("Train sentence : " + sentence)
# Out:
# Train sentence : All live births > or = 23 weeks at the University of Vermont in 1995 ( n = 2395 ) were retrospectively analyzed for delivery route , indication for cesarean , gestational age , parity , and practice group ( to reflect risk status )
# Train sentence : The total cesarean rate was 14.4 % ( 344 of 2395 ) , and the primary rate was 11.4 % ( 244 of 2144 )
# Train sentence : Abnormal presentation was the most common indication ( 25.6 % , 88 of 344 )
# Train sentence : The `` corrected '' cesarean rate ( maternal-fetal medicine and transported patients excluded ) was 12.4 % ( 273 of 2194 ) , and the `` corrected '' primary rate was 9.6 % ( 190 of 1975 )
# Train sentence : Arrest of dilation was the most common indication in both `` corrected '' subgroups ( 23.4 and 24.6 % , respectively )

# %%
test_sentences = convert_to_sentences(test_words)

# print first 5 test sentences
for sentence in test_sentences[:5]:
    print("Test sentence : " + sentence)
# Out:
# Test sentence : Furthermore , when all deliveries were analyzed , regardless of risk status but limited to gestational age > or = 36 weeks , the rates did not change ( 12.6 % , 280 of 2214 ; primary 9.2 % , 183 of 1994 )
# Test sentence : As the ambient temperature increases , there is an increase in insensible fluid loss and the potential for dehydration
# Test sentence : The daily high temperature ranged from 71 to 104 degrees F and AFI values ranged from 1.7 to 24.7 cm during the study period
# Test sentence : There was a significant correlation between the 2- , 3- , and 4-day mean temperature and AFI , with the 4-day mean being the most significant ( r = 0.31 , p & # 60 ; 0.001 )
# Test sentence : Fluctuations in ambient temperature are inversely correlated to changes in AFI

# %% [markdown]
# ## Count the number of sentences in the processed train and test dataset

# %%
print("Sentences count in train dataset", len(train_sentences))
print("Sentences count in test dataset", len(test_sentences))
# Out:
# Sentences count in train dataset 2599
# Sentences count in test dataset 1056

# %% [markdown]
# ## Count the number of lines of labels in the processed train and test dataset.

# %%
train_labels = convert_to_sentences(train_labels_words)
print("Sentences count in training labels", len(train_labels))

test_labels = convert_to_sentences(test_labels_words)
print("Sentences count in test labels", len(test_labels))
# Out:
# Sentences count in training labels 2599
# Sentences count in test labels 1056

# %% [markdown]
# ### Concept Identification
# We will first explore what are the various concepts present in the dataset. For this, we will use PoS Tagging.

# %%
# Creating a combined dataset from training and test sentences, since this is an Exploratory analysis.
total = train_sentences + test_sentences
print("Total number of sentences in train and test dataset : {}".format(len(total)))
# Out:
# Total number of sentences in train and test dataset : 3655

# %% [markdown]
# ### Extract those tokens which have NOUN or PROPN as their PoS tag and find their frequency

# %%
noun_pron = []      
pos_tag = []
for sentence in total:
    for token in model(sentence):
        if token.pos_ in ['NOUN', 'PROPN']:
           noun_pron.append(token.text)
           pos_tag.append(token.pos_)
print("Total number of tokens in train and test dataset with PoS tag of 'NOUN' or 'PROPN': {}".format(len(noun_pron)))
# Out:
# Total number of tokens in train and test dataset with PoS tag of 'NOUN' or 'PROPN': 24373

# %%
print("Total number of pos tags in train and test dataset with PoS tag of 'NOUN' or 'PROPN': {}".format(len(pos_tag)))
# Out:
# Total number of pos tags in train and test dataset with PoS tag of 'NOUN' or 'PROPN': 24373

# %% [markdown]
# ### Print the top 25 most common tokens with NOUN or PROPN PoS tags

# %%
import pandas as pd
from nltk import FreqDist

word_frequency = FreqDist(noun_pron)
pd.DataFrame(word_frequency.most_common(25), columns=["Sentence", "Count"])
# Out:
#         Sentence  Count
# 0       patients    492
# 1      treatment    281
# 2              %    247
# 3         cancer    200
# 4        therapy    175
# 5          study    153
# 6        disease    141
# 7           cell    140
# 8           lung    116
# 9          group     94
# 10  chemotherapy     88
# 11          gene     87
# 12       effects     85
# 13         women     77
# 14       results     77
# 15           use     73
# 16          risk     71
# 17         cases     71
# 18       surgery     71
# 19      analysis     70
# 20          rate     67
# 21      response     66
# 22      survival     65
# 23      children     64
# 24        effect     63

# %% [markdown]
# ## Defining features for CRF
# ### list of features used:
#
# - f1 = input word is in lower case;
# - f2 = last 3 characters of word;
# - f3 = last 2 characters of word;
# - f4 = 1; if the word is in uppercase, 0 otherwise;
# - f5 = 1; if word is a number; otherwise, 0
# - f6= 1; if the word starts with a capital letter; otherwise, 0
#
# extra feature: if pos > 0 :
#
# - fx1 = prev_word to lower
# - fx2 = prev_word is upper
# - fx3 = prev_word is digits
# - fx4 = prev_word starts with capital letter
#
# else:
#
# - fx1 = BEG(beginning of text)
# - if pos reached end:
# - fx1 = ENd(ending of text)

# %%
# Let's define the features to get the feature value for one word.
def getFeaturesForOneWord(sentence, pos):
    word = sentence[pos]

    features = [
    'word.lower=' + word.lower(), # serves as word id
    'word[-3:]=' + word[-3:],     # last three characters
    'word[-2:]=' + word[-2:],     # last two characters
    'word.isupper=%s' % word.isupper(),  # is the word in all uppercase
    'word.isdigit=%s' % word.isdigit(),  # is the word a number
    'word.startsWithCapital=%s' % word[0].isupper(), # is the word starting with a capital letter
    ]

    #Use the previous word also while defining features
    if(pos > 0):
        prev_word = sentence[pos-1]
        features.extend([
        'prev_word.lower=' + prev_word.lower(), 
        'prev_word.isupper=%s' % prev_word.isupper(),
        'prev_word.isdigit=%s' % prev_word.isdigit(),
        'prev_word.startsWithCapital=%s' % prev_word[0].isupper(),
    ])
    # Mark the begining and the end words of a sentence correctly in the form of features.
    else:
        features.append('BEG') # feature to track begin of sentence 

    if(pos == len(sentence)-1):
        features.append('END') # feature to track end of sentence

    return features

# %% [markdown]
# ### Getting the features
# #### Write a code/function to get the features for a sentence

# %%
# Write a code to get features for a sentence.
def getFeaturesForOneSentence(sentence):
  sentence_list = sentence.split()
  return [getFeaturesForOneWord(sentence_list, pos) for pos in range(len(sentence_list))]

# %%
# Write a code to get the labels for a sentence.
# Apply function 'getFeaturesForOneSentence' to get features on a single sentence which is at index value 5 in train_sentences
sample_sentence = train_sentences[1]
print(sample_sentence)

features = getFeaturesForOneSentence(sample_sentence)
features[2]
# Out:
# The total cesarean rate was 14.4 % ( 344 of 2395 ) , and the primary rate was 11.4 % ( 244 of 2144 )
# ['word.lower=cesarean',
#  'word[-3:]=ean',
#  'word[-2:]=an',
#  'word.isupper=False',
#  'word.isdigit=False',
#  'word.startsWithCapital=False',
#  'prev_word.lower=total',
#  'prev_word.isupper=False',
#  'prev_word.isdigit=False',
#  'prev_word.startsWithCapital=False']

# %%
sample_sentence = train_sentences[1]
print(sample_sentence)

features = getFeaturesForOneSentence(sample_sentence)
features[0]
# Out:
# The total cesarean rate was 14.4 % ( 344 of 2395 ) , and the primary rate was 11.4 % ( 244 of 2144 )
# ['word.lower=the',
#  'word[-3:]=The',
#  'word[-2:]=he',
#  'word.isupper=False',
#  'word.isdigit=False',
#  'word.startsWithCapital=True',
#  'BEG']

# %% [markdown]
# ### Write a code/function to get the labels of a sentence

# %%
# Write a code to get the labels for a sentence.
def getLabelsInListForOneSentence(labels):
    return labels.split()

# %% [markdown]
# ### Define input and target variables
# #### Correctly computing X and Y sequence matrices for training and test data. Check that both sentences and labels are processed
#
# #### Define the features' values for each sentence as input variable for CRF model in test and the train dataset

# %%
X_train = [getFeaturesForOneSentence(sentence) for sentence in train_sentences]
X_test = [getFeaturesForOneSentence(sentence) for sentence in test_sentences]

# %% [markdown]
# ### Define the labels as the target variable for test and the train dataset

# %%
y_train = [getLabelsInListForOneSentence(label) for label in train_labels]
y_test = [getLabelsInListForOneSentence(label) for label in test_labels]

# %% [markdown]
# ## Build the CRF Model

# %%
# Build the CRF model.
import sklearn_crfsuite
from sklearn_crfsuite import metrics

# %%
# Build the CRF model.
crf = sklearn_crfsuite.CRF(max_iterations=100)
crf.fit(X_train, y_train)
# Out:
# CRF(max_iterations=100)

# %%
import eli5
# Show top 20 weights of model across all labels
eli5.show_weights(crf, top=20)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>D</th>
#
#                 <th>O</th>
#
#                 <th>T</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>D</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.00%)" title="D &rArr; D">
#                             4.233
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.37%)" title="D &rArr; O">
#                             -1.273
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 85.85%)" title="D &rArr; T">
#                             -2.582
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 92.53%)" title="O &rArr; D">
#                             1.037
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.85%)" title="O &rArr; O">
#                             1.174
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.02%)" title="O &rArr; T">
#                             -1.349
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>T</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="T &rArr; D">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 93.78%)" title="T &rArr; O">
#                             0.798
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.28%)" title="T &rArr; T">
#                             3.852
#                         </td>
#
#                 </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=D
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=O
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=T
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.456
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower=infection
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.046
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]=ia
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.995
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-3:]=tis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.883
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower=disease
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.824
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower=syndrome
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.815
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower=diabetes
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.27%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.657
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower=tumors
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.44%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.629
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]=lc
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.604
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]=ma
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.489
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower=cancers
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.434
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         prev_word.lower=against
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.424
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; t

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Predict the labels of each of the tokens in each sentence of the test dataset that has been pre processed earlier.

# %%
y_pred = crf.predict(X_test)

# %% [markdown]
# Calculate the f1 score using the actual labels and the predicted labels of the test dataset.

# %%
# Calculate the f1 score using the test data
f1_score = metrics.flat_f1_score(y_test, y_pred, average='weighted')
print("F1 score:", f1_score)
# Out:
# F1 score: 0.9025814007854693

# %% [markdown]
# ### Identifying Diseases and Treatments using Custom NER
# #### We now use the CRF model's prediction to prepare a record of diseases identified in the corpus and treatments used for the diseases.
#
# #### Create the logic to get all the predicted treatments (T) labels corresponding to each disease (D) label in the test dataset.

# %% [markdown]
# ### Creating data frame for Disease and Treatments

# %%
import numpy as np
dataframe = pd.DataFrame([], columns=["Disease", "Treatments"])

import numpy as np
dataframe = pd.DataFrame([], columns=["Disease", "Treatments"])

for i in range(len(y_pred)):
  p_val = y_pred[i]
  dise = ""
  treat = ""

  DTO = set(p_val)
  if "D" in DTO and "T" in DTO:

    for j in range(len(p_val)):
      if p_val[j] == 'D':
        dise += test_sentences[i].split()[j] + " "
      elif p_val[j] == 'T':
        treat += test_sentences[i].split()[j] + " "

    dise = dise.strip()
    treat = treat.strip()

    present = dataframe.loc[(dataframe.Disease == dise), ["Disease"]]
    if present.size:
      treatment_df = dataframe.loc[(dataframe.Disease == dise), ["Treatments"]]
      treatment = treatment_df.values.tolist()
      treatment.extend([treat])
      dataframe.loc[(dataframe.Disease == dise), ["Treatments"]] = [[treatment]]

    else:
      dataframe = pd.concat([dataframe, pd.DataFrame([[dise, treat]], columns=dataframe.columns )])

dataframe = dataframe.set_index(np.arange(dataframe.shape[0]))
dataframe
# Out:
#                                               Disease  \
# 0                           hereditary retinoblastoma
# 1   unstable angina or non-Q-wave myocardial infar...
# 2                             coronary-artery disease
# 3                                          cellulitis
# 4                          early Parkinson 's disease
# ..                                                ...
# 82                temporomandibular joint arthropathy
# 83                       severe secondary peritonitis
# 84          hepatic metastases from colorectal cancer
# 85                              chronic renal failure
# 86                          epithelial ovarian cancer
#
#                                            Treatments
# 0                                        radiotherapy
# 1                                       roxithromycin
# 2                          Antichlamydial antibiotics
# 3      G-CSF therapy intravenous antibiotic treatment
# 4                              Ropinirole monotherapy
# ..                                                ...
# 82                             arthroscopic treatment
# 83                                Surgical management
# 84  Hepatic arterial infusion of chemotherapy afte...
# 85                                            Epoetin
# 86                             High-dose chemotherapy
#
# [87 rows x 2 columns]

# %% [markdown]
# ### Predict the treatment for the disease name: 'hereditary retinoblastoma'

# %%
disease = 'hereditary retinoblastoma'
dataframe.loc[(dataframe.Disease == disease), ["Disease", "Treatments"]]
# Out:
#                      Disease    Treatments
# 0  hereditary retinoblastoma  radiotherapy

# %% [markdown]
# ## Model 2 : POS tag in feature

# %%
# Let's define the features to get the feature value for one word.
def getFeaturesForOneWord(sentence, pos, pos_tags):
    word = sentence[pos]

    features = [
    'word.lower=' + word.lower(), # serves as word id
    'word[-3:]=' + word[-3:],     # last three characters
    'word[-2:]=' + word[-2:],     # last two characters
    'word.isupper=%s' % word.isupper(),  # is the word in all uppercase
    'word.isdigit=%s' % word.isdigit(),  # is the word a number
    'word.startsWithCapital=%s' % word[0].isupper(), # is the word starting with a capital letter
    'word.pos=' + pos_tags[pos] # adding POS tag here
    ]

    #Use the previous word also while defining features
    if(pos > 0):
        prev_word = sentence[pos-1]
        features.extend([
        'prev_word.lower=' + prev_word.lower(), 
        'prev_word.isupper=%s' % prev_word.isupper(),
        'prev_word.isdigit=%s' % prev_word.isdigit(),
        'prev_word.startsWithCapital=%s' % prev_word[0].isupper(),
        'prev_word.pos=' + pos_tags[pos-1] # adding POS tag here
    ])
    # Mark the begining and the end words of a sentence correctly in the form of features.
    else:
        features.append('BEG') # feature to track begin of sentence 

    if(pos == len(sentence)-1):
        features.append('END') # feature to track end of sentence

    return features

# %%
# Function to get features for a sentence.
def getFeaturesForOneSentence(sentence):
    
    # We need to get the pos_tags to be passed to the function
    processed_sent = model(sentence)
    postags = []
    deptags = []
    
    for each_token in processed_sent:
        postags.append(each_token.pos_)
        deptags.append(each_token.dep_) # add dep
    
    sentence_list = sentence.split()
    return [getFeaturesForOneWord(sentence_list, pos, postags) for pos in range(len(sentence_list))]

# %%
# Apply function 'getFeaturesForOneSentence' to get features on a single sentence which is at index value 5 in train_sentences
sample_sentence = train_sentences[1]
print(sample_sentence)

features = getFeaturesForOneSentence(sample_sentence)
features[2]
# Out:
# The total cesarean rate was 14.4 % ( 344 of 2395 ) , and the primary rate was 11.4 % ( 244 of 2144 )
# ['word.lower=cesarean',
#  'word[-3:]=ean',
#  'word[-2:]=an',
#  'word.isupper=False',
#  'word.isdigit=False',
#  'word.startsWithCapital=False',
#  'word.pos=ADJ',
#  'prev_word.lower=total',
#  'prev_word.isupper=False',
#  'prev_word.isdigit=False',
#  'prev_word.startsWithCapital=False',
#  'prev_word.pos=ADJ']

# %%
# Apply function 'getFeaturesForOneSentence' to get features on a single sentence which is at index value 5 in train_sentences
sample_sentence = train_sentences[1]
print(sample_sentence)

features = getFeaturesForOneSentence(sample_sentence)
features[0]
# Out:
# The total cesarean rate was 14.4 % ( 344 of 2395 ) , and the primary rate was 11.4 % ( 244 of 2144 )
# ['word.lower=the',
#  'word[-3:]=The',
#  'word[-2:]=he',
#  'word.isupper=False',
#  'word.isdigit=False',
#  'word.startsWithCapital=True',
#  'word.pos=DET',
#  'BEG']

# %%
# Write a code to get the labels for a sentence.
def getLabelsInListForOneSentence(labels):
    return labels.split()

# %%
X_train = [getFeaturesForOneSentence(sentence) for sentence in train_sentences]
X_test = [getFeaturesForOneSentence(sentence) for sentence in test_sentences]

# %% [markdown]
# ### Define the labels as the target variable for test and the train dataset

# %%
y_train = [getLabelsInListForOneSentence(label) for label in train_labels]
y_test = [getLabelsInListForOneSentence(label) for label in test_labels]

# %%
# Build the CRF model.
crf = sklearn_crfsuite.CRF(max_iterations=100)

# %%
crf.fit(X_train, y_train)
# Out:
# CRF(max_iterations=100)

# %%
import eli5
# Show top 20 weights of model across all labels
eli5.show_weights(crf, top=20)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>D</th>
#
#                 <th>O</th>
#
#                 <th>T</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>D</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.00%)" title="D &rArr; D">
#                             4.68
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 90.48%)" title="D &rArr; O">
#                             -1.621
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 87.66%)" title="D &rArr; T">
#                             -2.347
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 90.43%)" title="O &rArr; D">
#                             1.634
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 92.08%)" title="O &rArr; O">
#                             1.247
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 89.54%)" title="O &rArr; T">
#                             -1.854
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>T</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="T &rArr; D">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 92.70%)" title="T &rArr; O">
#                             1.108
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.58%)" title="T &rArr; T">
#                             4.163
#                         </td>
#
#                 </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=D
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=O
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=T
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.547
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower=infection
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.956
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower=disease
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.903
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-3:]=tis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.78%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.888
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]=ia
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.863
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower=diabetes
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.775
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower=tumors
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.769
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]=lc
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.652
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower=syndrome
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.573
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-3:]=clc
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.97%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.536
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]=ma
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.505
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-3:]=cer
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.431
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left;

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Evaluation
# Predict the labels of each of the tokens in each sentence of the test dataset that has been pre processed earlier.

# %%
y_pred = crf.predict(X_test)

# %% [markdown]
# ### Calculate the f1 score using the actual labels and the predicted labels of the test dataset.

# %%
f1_score = metrics.flat_f1_score(y_test, y_pred, average='weighted')
print("F1 score:", f1_score)
# Out:
# F1 score: 0.9070569695262888

# %% [markdown]
# ### Creating Dataframe for Disease and Treatments

# %%
import numpy as np
dataframe = pd.DataFrame([], columns=["Disease", "Treatments"])

import numpy as np
dataframe = pd.DataFrame([], columns=["Disease", "Treatments"])

for i in range(len(y_pred)):
  p_val = y_pred[i]
  dise = ""
  treat = ""

  DTO = set(p_val)
  if "D" in DTO and "T" in DTO:

    for j in range(len(p_val)):
      if p_val[j] == 'D':
        dise += test_sentences[i].split()[j] + " "
      elif p_val[j] == 'T':
        treat += test_sentences[i].split()[j] + " "

    dise = dise.strip()
    treat = treat.strip()

    present = dataframe.loc[(dataframe.Disease == dise), ["Disease"]]
    if present.size:
      treatment_df = dataframe.loc[(dataframe.Disease == dise), ["Treatments"]]
      treatment = treatment_df.values.tolist()
      treatment.extend([treat])
      dataframe.loc[(dataframe.Disease == dise), ["Treatments"]] = [[treatment]]

    else:
      dataframe = pd.concat([dataframe, pd.DataFrame([[dise, treat]], columns=dataframe.columns )])

dataframe = dataframe.set_index(np.arange(dataframe.shape[0]))
dataframe
# Out:
#                                                Disease  \
# 0                            hereditary retinoblastoma
# 1                                myocardial infarction
# 2    unstable angina or non-Q-wave myocardial infar...
# 3                              coronary-artery disease
# 4               primary pulmonary hypertension ( PPH )
# ..                                                 ...
# 105                temporomandibular joint arthropathy
# 106                       severe secondary peritonitis
# 107          hepatic metastases from colorectal cancer
# 108                              chronic renal failure
# 109                          epithelial ovarian cancer
#
#                                             Treatments
# 0                                         radiotherapy
# 1    warfarin with 80 mg aspirin , or 1 mg warfarin...
# 2                                        roxithromycin
# 3                           Antichlamydial antibiotics
# 4                                        fenfluramines
# ..                                                 ...
# 105                             arthroscopic treatment
# 106                                Surgical management
# 107  Hepatic arterial infusion of chemotherapy afte...
# 108                                            Epoetin
# 109                             High-dose chemotherapy
#
# [110 rows x 2 columns]

# %% [markdown]
# ### Predict the treatment for the disease name: 'hereditary retinoblastoma'

# %%
disease = 'hereditary retinoblastoma'
dataframe.loc[(dataframe.Disease == disease), ["Disease", "Treatments"]]
# Out:
#                      Disease    Treatments
# 0  hereditary retinoblastoma  radiotherapy

# %% [markdown]
# ### Final Task: Disease-Treatment Dictionary

# %%
from tqdm import tqdm  # optional for progress bar

def sent2features(sentences):
    all_features = []
    for doc in tqdm(nlp.pipe(sentences, disable=["ner"]), total=len(sentences)):
        tokens = [token.text for token in doc]
        feats = []
        for i, token in enumerate(doc):
            features = {
                'word.lower': token.text.lower(),
                'word[-3:]': token.text[-3:],
                'word.istitle': token.is_title,
                'word.isdigit': token.is_digit,
                'postag': token.pos_,
            }
            if i > 0:
                prev = doc[i-1]
                features.update({
                    '-1:word.lower': prev.text.lower(),
                    '-1:postag': prev.pos_,
                })
            else:
                features['BOS'] = True
            if i < len(doc)-1:
                nxt = doc[i+1]
                features.update({
                    '+1:word.lower': nxt.text.lower(),
                    '+1:postag': nxt.pos_,
                })
            else:
                features['EOS'] = True
            feats.append(features)
        all_features.append(feats)
    return all_features

# %%
X_train = sent2features(train_sentences)
X_test = sent2features(test_sentences)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 2599/2599 [00:03<00:00, 812.40it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 1056/1056 [00:01<00:00, 771.61it/s]

# %%
for i, (x, y) in enumerate(zip(X_train, Y_train)):
    if len(x) != len(y):
        print(f"Mismatch at index {i}: Features = {len(x)}, Labels = {len(y)}")
        print("Sentence:", train_sentences[i])
        print("Labels:", train_labels[i])
        break
# Out:
# Mismatch at index 3: Features = 42, Labels = 38
# Sentence: The `` corrected '' cesarean rate ( maternal-fetal medicine and transported patients excluded ) was 12.4 % ( 273 of 2194 ) , and the `` corrected '' primary rate was 9.6 % ( 190 of 1975 )
# Labels: O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O

# %%
cleaned_X_train = []
cleaned_Y_train = []

for x, y in zip(X_train, Y_train):
    if len(x) == len(y):
        cleaned_X_train.append(x)
        cleaned_Y_train.append(y)

X_train = cleaned_X_train
Y_train = cleaned_Y_train

# %%
# Make sure your model is trained
crf.fit(X_train, Y_train)

# Predict labels
pred_labels = crf.predict(X_test)

# Now extract the disease-treatment dictionary
from collections import defaultdict

def extract_disease_treatment(sentences, labels):
    disease_treatment = defaultdict(set)

    for sent, label_seq in zip(sentences, labels):
        diseases = []
        treatments = []
        for word, label in zip(sent.split(), label_seq):
            if label == 'D':
                diseases.append(word)
            elif label == 'T':
                treatments.append(word)
        for d in diseases:
            disease_treatment[d].update(treatments)
    
    return disease_treatment

# Apply function
dt_dict = extract_disease_treatment(test_sentences, pred_labels)

# Print some results
for disease, treatments in list(dt_dict.items())[:10]:
    print(f"{disease} : {', '.join(treatments)}")
# Out:
# gestational : control, glycemic, good
# diabetes : control, glycemic, good
# cases : control, glycemic, good
# nonimmune : Trisomy
# hydrops : Trisomy
# fetalis : Trisomy
# preeclampsia : intrauterine, insemination
# severe : Surgical, systemic, therapy, chemotherapy, transplantation, glucocorticoid, pulse, management, organ, treatments, and
# ovarian :
# cancer : of, ,, iodine, amifostine, (, radical, photodynamic, cisplatin, chemotherapy, organ, adjuvant, radiation, radiotherapy, sclc, and, undergone, advanced, Hepatic, mastectomy, conclusion, arterial, therapy, concurrent, :, prostatectomy, carboplatin, oral, thoracic, Hormone, vaccination, subcutaneous, early, or, intravenous, Elective, 125, leucovorin, paclitaxel, plus, vinorelbine, replacement, irradiation, mitomycin, for, infusion, pc, oxaliplatin, C, vc, vip, disease, interstitial, surgery, combination, Nerve-sparing, ), transplantation, drugs, as

# %%
# Search for hereditary retinoblastoma
for disease in dt_dict:
    if "hereditary retinoblastoma" in disease.lower():
        print(f"Disease: {disease}")
        print("Predicted Treatment(s):", ', '.join(dt_dict[disease]))

# %%
print("Diseases found:")
for disease in dt_dict:
    print("-", disease)
# Out:
# Diseases found:
# - gestational
# - diabetes
# - cases
# - nonimmune
# - hydrops
# - fetalis
# - preeclampsia
# - severe
# - ovarian
# - cancer
# - breast
# - diagnosis
# - prostate
# - hereditary
# - multiple
# - sclerosis
# - retinoblastoma
# - pericardial
# - effusions
# - hearing
# - aids
# - epilepsy
# - coronary-artery
# - disease
# - early-stage
# - cervical
# - carcinoma
# - in
# - terms
# - but
# - not
# - mild
# - to
# - moderate
# - pain
# - myofascial
# - trigger
# - point
# - confirmed
# - infection
# - primary
# - pulmonary
# - hypertension
# - (
# - PPH
# - )
# - Curtis
# - foot
# - infections
# - diabetic
# - intracranial
# - hemorrhage
# - rheumatoid
# - arthritis
# - arthrodesis
# - 's
# - sore
# - throat
# - upper
# - respiratory
# - conditions
# - mean
# - analgesia
# - chronic
# - neutropenia
# - Crohn
# - female
# - stress
# - urinary
# - incontinence
# - corpal
# - gastritis
# - proteinuric
# - myocardial
# - amyloidosis
# - heart
# - failure
# - cardiac
# - amyloid
# - AL
# - Retinopathy
# - Intra-abdominal
# - injury
# - was
# - present
# - intra-abdominal
# - 36
# - tangential
# - gunshot
# - wounds
# - may
# - acquired
# - hyperammonemia
# - major
# - embolism
# - congestive
# - years
# - previously
# - had
# - loss
# - Darier
# - tumor
# - necrosis
# - factor-alpha
# - hemorrhagic
# - shock
# - symptoms
# - attributable
# - non-obstructive
# - azoospermia
# - ,
# - TEFNA
# - lymphoma
# - whereas
# - or
# - red
# - cell
# - glycolysis
# - acute
# - lymphoblastic
# - leukaemias
# - hormonal
# - dysfunction
# - endometriosis
# - hyperlipidemias
# - Hepatocerebral
# - degeneration
# - portal
# - systemic
# - encephalopathy
# - mastitis
# - Rhesus
# - haemolytic
# - duodenal
# - ulcer
# - childhood
# - schizophrenia
# - congenital
# - adrenal
# - hyperplasia
# - Laennec
# - cirrhosis
# - renal
# - stones
# - stone
# - anomalies
# - Ovarian
# - Perforated
# - peptic
# - Gynaecological
# - diuresis
# - Rhinitis
# - piglet
# - influenza
# - metastasis
# - of
# - laryngeal
# - carcinomas
# - and
# - colorectal
# - children
# - leukaemia
# - gastrointestinal
# - tumours
# - attention
# - deficit
# - hyperactivity
# - disorder
# - Chlamydia
# - trachomatis
# - anemia
# - end-stage
# - malignant
# - lymphomas
# - temporal
# - arteritis
# - coronary
# - Russia
# - restenosis
# - oral
# - refractory
# - section
# - Spontaneous
# - splenic
# - rupture
# - accidental
# - hypothermia
# - victims
# - HIV/AIDS
# - Blastocystis
# - hominis
# - .
# - stomach
# - Ovine
# - Johne
# - lupus
# - erythematosus
# - Metastatic
# - mesothelioma
# - presenting
# - as
# - colonic
# - polyps
# - :
# - postoperative
# - murine
# - hepatitis
# - virus
# - strain
# - 3
# - Small
# - lung
# - distress
# - syndrome
# - mantle
# - Postraumatic
# - Stress
# - Disorder
# - Pendred
# - Infectious
# - diseases
# - soft
# - tissue
# - sarcomas
# - bronchogenic
# - bilateral
# - cortical
# - lesions
# - cerebral
# - injuries
# - Coronary
# - endothelial
# - perfusion
# - defects
# - ectopic
# - pregnancy
# - Alzheimer
# - Eisenmenger
# - continuous
# - ambulatory
# - peritoneal
# - dialysis
# - sickle
# - intractable
# - seizures
# - infarction
# - is
# - associated
# - Gorlin
# - aplasia
# - hypercholesterolemia
# - AIDS
# - exceptionalism
# - Myoepithelial
# - tuberous
# - complex
# - malaria
# - psoriasis
# - hemiretinal
# - vein
# - occlusion
# - Acute
# - obstructive
# - hydrocephalus
# - complicating
# - bacterial
# - meningitis
# - pouchitis
# - Epilepsy
# - endoluminal
# - hemoptysis
# - dose
# - control
# - suppression
# - non-small
# - advanced
# - nsclc
# - manageable
# - toxicities
# - recurrent
# - adenocarcinoma
# - common
# - cold
# - abdominal
# - pleuritic
# - fungal
# - inflammatory
# - skin
# - unresectable
# - stage
# - iii
# - sclc
# - continue
# - extracorporeal
# - photopheresis
# - limited
# - small
# - pleural
# - from
# - were
# - retrospectively
# - reviewed
# - supraclavicular
# - node
# - metastases
# - low
# - doses
# - cisplatin
# - esophageal
# - tracheobronchial
# - stenoses
# - osteogenic
# - sarcoma
# - 0
# - brain
# - have
# - the
# - metastatic
# - achieved
# - non-hodgkin
# - combination
# - ad
# - squamous
# - small-cell
# - non
# - --
# - compared
# - expression
# - head
# - neck
# - poisoning
# - should
# - receive
# - received
# - thrice
# - ventricular
# - tachycardia
# - non-functioning
# - endocrine
# - pancreatic
# - with
# - progressive
# - accompanying
# - cholestasis
# - autoimmune
# - syringomyelia
# - spinal
# - adhesive
# - arachnoiditis
# - biliary
# - colic
# - dyskinesia
# - patients
# - paranasal
# - sinuses
# - aspergilloma
# - viral
# - asthma
# - self-management
# - pneumonia
# - lice
# - rhinovirus
# - bronchitis
# - persistent
# - C
# - viremia
# - duodenogastric
# - reflux
# - hypoxemia
# - Haemophilus
# - influenzae
# - asthmatic
# - RSV
# - bronchiolitis
# - sclerosing
# - cholangitis
# - found
# - ischemic
# - autologous
# - middle
# - artery
# - benign
# - prostatic
# - herbal
# - medicine
# - large
# - midline
# - incisional
# - hernias
# - large-bowel
# - when
# - administered
# - phaeochromocytoma
# - melanoma
# - myelogenous
# - leukemia
# - achalasia
# - irritable
# - bowel
# - proximal
# - hypospadias
# - tumor-derived
# - Haematoma
# - block
# - versus
# - intravenous
# - regional
# - anaesthesia
# - line
# - B16
# - uveal
# - bronchiectasis
# - noncirrhotic
# - non-Hodgkin
# - ischemia
# - odontogenic
# - angiogenesis
# - Barrett
# - esophagus
# - hemolytic
# - endometrial
# - association
# - atrial
# - fibrillation
# - at
# - renovascular
# - repetitive
# - a
# - acoustic
# - neuroma
# - palsy
# - postvitrectomy
# - vitreous
# - carbon
# - monoxide
# - B
# - pertussis
# - temporomandibular
# - joint
# - arthropathy
# - pseudo-obstruction
# - perioperative
# - mortality
# - secondary
# - peritonitis
# - hepatic
# - diverticular
# - stable
# - Poliomyelitis
# - prevention

# %% [markdown]
# ## Get Treatment for Specific Disease

# %%
found = False
for disease in dt_dict:
    if "retinoblastoma" in disease.lower():
        print(f"Disease: {disease}")
        print("Predicted Treatment(s):", ', '.join(dt_dict[disease]))
        found = True

if not found:
    print("No predicted disease found for 'retinoblastoma'")
# Out:
# Disease: retinoblastoma
# Predicted Treatment(s): radiotherapy
